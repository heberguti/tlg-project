# %% [markdown]
# <a href="https://colab.research.google.com/github/heberguti/tlg-project/blob/main/migrationMoviesToDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install firebase-admin

# %%
import firebase_admin
from firebase_admin import credentials, firestore
import pandas as pd

path = "/content/"

cred = credentials.Certificate(path + "movies-tlg.json")
firebase_admin.initialize_app(cred)

# %%
db = firestore.client()
doc_ref = db.collection(u'movie')
df = pd.read_csv(path+ 'movies.csv')
tmp = df.to_dict(orient = 'records')
list(map(lambda x: doc_ref.add(x), tmp))
# Out:
# [(DatetimeWithNanoseconds(2025, 3, 8, 19, 25, 55, 821712, tzinfo=datetime.timezone.utc),
#   <google.cloud.firestore_v1.document.DocumentReference at 0x78c76fbd1f90>),
#  (DatetimeWithNanoseconds(2025, 3, 8, 19, 25, 55, 900844, tzinfo=datetime.timezone.utc),
#   <google.cloud.firestore_v1.document.DocumentReference at 0x78c7b6d56e90>),
#  (DatetimeWithNanoseconds(2025, 3, 8, 19, 25, 56, 118219, tzinfo=datetime.timezone.utc),
#   <google.cloud.firestore_v1.document.DocumentReference at 0x78c771fde0d0>),
#  (DatetimeWithNanoseconds(2025, 3, 8, 19, 25, 56, 206376, tzinfo=datetime.timezone.utc),
#   <google.cloud.firestore_v1.document.DocumentReference at 0x78c770faa550>),
#  (DatetimeWithNanoseconds(2025, 3, 8, 19, 25, 56, 336563, tzinfo=datetime.timezone.utc),
#   <google.cloud.firestore_v1.document.DocumentReference at 0x78c7708b0e50>),
#  (DatetimeWithNanoseconds(2025, 3, 8, 19, 25, 56, 407197, tzinfo=datetime.timezone.utc),
# ...
